# %%
# %cd MWPToolkit

import nltk
nltk.download('punkt')
# Out:
# /home/dlpc01/Math Word Problem Solving/MWPToolkit
# [nltk_data] Downloading package punkt to /home/dlpc01/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
! python run_mwptoolkit.py --model=DeBERTaGen --dataset=paramawps --task_type=single_equation --equation_fix=infix --k_fold=5 --test_step=5 --gpu_id=0 --epoch_nums=50
# Out:
# 08 Mar 23:19    INFO random_seed=2021
# use_gpu=True
# max_output_len=30
# gpu_id=0
# test_step=5
# load_best_config=False
# supervising_mode=fully_supervised
# rebuild=False
# validset_divide=True
# shuffle=False
# model_config_file=mwptoolkit/properties/model/DeBERTaGen.json
# best_config_file=mwptoolkit/properties/best_config/DeBERTaGen_paramawps.json
# dataset_config_file=mwptoolkit/properties/dataset/paramawps.json
# dataset_dir=dataset/paramawps
# checkpoint_file=checkpoint/DeBERTaGen-paramawps.pth
# trained_model_dir=trained_model/DeBERTaGen-paramawps
# log_file=log/DeBERTaGen-paramawps.log
# output_dir=result/DeBERTaGen-paramawps
# checkpoint_dir=checkpoint/DeBERTaGen-paramawps
# min_word_keep=5
# min_generate_keep=5
# mask_symbol=number
# single=False
# linear=True
# language=en
# train_batch_size=8
# test_batch_size=8
# source_equation_fix=infix
# pretrained_model=microsoft/deberta-base
# embedding_size=768
# ffn_size=1024
# num_decoder_layers=4
# num_heads=16
# ...

# %%
! python run_mwptoolkit.py --model=DeBERTaGen --dataset=mawps --task_type=single_equation --equation_fix=infix --k_fold=5 --test_step=5 --gpu_id=0
# Out:
# 08 Mar 22:49    INFO random_seed=2021
# use_gpu=True
# max_output_len=30
# gpu_id=0
# test_step=5
# load_best_config=False
# supervising_mode=fully_supervised
# rebuild=False
# validset_divide=True
# shuffle=False
# model_config_file=mwptoolkit/properties/model/DeBERTaGen.json
# best_config_file=mwptoolkit/properties/best_config/DeBERTaGen_mawps.json
# dataset_config_file=mwptoolkit/properties/dataset/mawps.json
# dataset_dir=dataset/mawps
# checkpoint_file=checkpoint/DeBERTaGen-mawps.pth
# trained_model_dir=trained_model/DeBERTaGen-mawps
# log_file=log/DeBERTaGen-mawps.log
# output_dir=result/DeBERTaGen-mawps
# checkpoint_dir=checkpoint/DeBERTaGen-mawps
# min_word_keep=5
# min_generate_keep=5
# mask_symbol=number
# single=False
# linear=True
# language=en
# train_batch_size=8
# test_batch_size=8
# source_equation_fix=infix
# pretrained_model=microsoft/deberta-base
# embedding_size=768
# ffn_size=1024
# num_decoder_layers=4
# num_heads=16
# embedding_dropout_ratio=0.5
# ...

# %%
! python run_mwptoolkit.py --model=BERTGen --dataset=paramawps --task_type=single_equation --equation_fix=infix --k_fold=5 --test_step=5 --gpu_id=0 --epoch_nums=50
# Out:
# 10 Mar 07:26    INFO random_seed=2021
# use_gpu=True
# max_output_len=30
# gpu_id=0
# test_step=5
# load_best_config=False
# supervising_mode=fully_supervised
# rebuild=False
# validset_divide=True
# shuffle=False
# model_config_file=mwptoolkit/properties/model/BERTGen.json
# best_config_file=mwptoolkit/properties/best_config/BERTGen_paramawps.json
# dataset_config_file=mwptoolkit/properties/dataset/paramawps.json
# dataset_dir=dataset/paramawps
# checkpoint_file=checkpoint/BERTGen-paramawps.pth
# trained_model_dir=trained_model/BERTGen-paramawps
# log_file=log/BERTGen-paramawps.log
# output_dir=result/BERTGen-paramawps
# checkpoint_dir=checkpoint/BERTGen-paramawps
# min_word_keep=5
# min_generate_keep=5
# mask_symbol=number
# single=False
# linear=True
# language=en
# train_batch_size=8
# test_batch_size=8
# source_equation_fix=infix
# pretrained_model=bert-base-uncased
# embedding_size=768
# ffn_size=1024
# num_decoder_layers=2
# num_heads=8
# embedding_dropout_ratio=0.5
# ...
