# %%
# %cd MWPToolkit
# Out:
# /home/dlpc01/Math Word Problem Solving/MWPToolkit

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/dlpc01/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
! python run_mwptoolkit.py --model=MathEN --dataset=paramawps --task_type=single_equation --equation_fix=infix --k_fold=5 --test_step=5 --gpu_id=1 --epoch_nums=50 --train_batch_size=32
# Out:
# 09 Mar 02:58    INFO random_seed=2021
# use_gpu=True
# max_output_len=30
# gpu_id=1
# test_step=5
# load_best_config=False
# supervising_mode=fully_supervised
# rebuild=False
# validset_divide=True
# shuffle=False
# model_config_file=mwptoolkit/properties/model/MathEN.json
# best_config_file=mwptoolkit/properties/best_config/MathEN_paramawps.json
# dataset_config_file=mwptoolkit/properties/dataset/paramawps.json
# dataset_dir=dataset/paramawps
# checkpoint_file=checkpoint/MathEN-paramawps.pth
# trained_model_dir=trained_model/MathEN-paramawps
# log_file=log/MathEN-paramawps.log
# output_dir=result/MathEN-paramawps
# checkpoint_dir=checkpoint/MathEN-paramawps
# min_word_keep=5
# min_generate_keep=5
# mask_symbol=number
# single=False
# linear=True
# language=en
# train_batch_size=32
# test_batch_size=32
# source_equation_fix=infix
# embedding_size=128
# hidden_size=512
# decode_hidden_size=512
# learning_rate=0.001
# embedding_learning_rate=1e-05
# decoder_rnn_cell_type=lstm
# ...
